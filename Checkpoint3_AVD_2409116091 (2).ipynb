# %% [markdown]
# #Visualisasi Data Dengan Studi Kasus Yang Sudah Ditentukan

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('Players.csv')

# %%
df
# Out:
#      Rank      Player  Gold  Silver  Bronze  S Tier  Earnings
# 0       1       zombs    13       5       1       1  $113,550
# 1       2     ShahZaM    13       4       1       1  $113,450
# 2       3        dapr    14       3       1       1  $112,870
# 3       4        SicK    12       3       1       1  $112,650
# 4       5        cNed    12       4       2       1  $107,735
# ..    ...         ...   ...     ...     ...     ...       ...
# 495   496         Kim     3       4       1       0    $5,555
# 496   497        Less     3       1       1       0    $5,543
# 497   498  Senhoachic     7       2       5       0    $5,537
# 498   499       chase    19      10       2       0    $5,531
# 499   500     Harmful     6       4       2       0    $5,530
#
# [500 rows x 7 columns]

# %% [markdown]
# **1. Visualisasi Pemain Berdasarkan Jenis Medali yang didapatkan**

# %%
plt.figure(figsize=(12, 6))
plt.bar(df['Gold'].value_counts().index, df['Gold'].value_counts().values, color='Orange')
plt.title('Jumlah Pemain Yang Mendapatkan Gold Medal')
plt.xlabel('Gold Medal')
plt.ylabel('Jumlah Pemain')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.bar(df['Silver'].value_counts().index, df['Silver'].value_counts().values, color='Blue')
plt.title('Jumlah Pemain Yang Mendapatkan Gold Silver')
plt.xlabel('Silver Medal')
plt.ylabel('Jumlah Pemain')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.bar(df['Bronze'].value_counts().index, df['Bronze'].value_counts().values, color='Brown')
plt.title('Jumlah Pemain Yang Mendapatkan Bronze')
plt.xlabel('Bronze Medal')
plt.ylabel('Jumlah Pemain')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# **2. Membuat Tabel Histogram untuk menentukan disribusinya**

# %%
plt.figure(figsize=(12, 6))
plt.hist(data['Earnings'], bins=15, color='purple')
plt.title('Distribusi dari Player Earnings')
plt.xlabel('Earnings')
plt.ylabel('Frekuensi')
plt.tight_layout()
plt.show()

# %% [markdown]
# **3. Menghitung Matriks Relasi Visualisasi Data dari Gold, Silver, Bronze dan Earningsnya**

# %%
correlation_matrix = data[['Gold', 'Silver', 'Bronze', 'Earnings']].corr()

plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap of Player Metrics')
plt.tight_layout()
plt.show()

# %% [markdown]
# #2. INSIGHT

# %% [markdown]
# ### **1. Visualisasi Pemain Berdasarkan Jenis Medali yang didapatkan**

# %% [markdown]
# - 3 Grafik BAR CHART tersebut menunjukkan medali medali yang didapatkan oleh para playes

# %% [markdown]
# - Jika semakin lama semakin banyak yang mendapatkan salah satu dari 3 medali, makan bar chart nya akan semakin banyak yang dapat didata

# %% [markdown]
# ### **2. Membuat Tabel Histogram untuk menentukan disribusinya**

# %% [markdown]
# - Grafik tersebut menunjukkan seberapa banyak distribusi dalam dunia kompetisi Valorant Esport

# %% [markdown]
# ### **3.Menghitung Matriks Relasi Visualisasi Data dari Gold, Silver, Bronze dan Earningsnya**

# %% [markdown]
# - Grafik ini menunjukkan seberapa besar matriks relasi dari visualisasi data medali dan earnings yang ada pada dataset
