# %% [markdown]
# #CHECKPOINT 2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# IN [ ] :

# %%
import pandas as pd

df = pd.read_csv("/content/drive/MyDrive/Players.csv")

# %% [markdown]
# OUT [ ]:

# %%
df.head()
# Out:
#    Rank   Player  Gold  Silver  Bronze  S Tier  Earnings
# 0     1    zombs    13       5       1       1  $113,550
# 1     2  ShahZaM    13       4       1       1  $113,450
# 2     3     dapr    14       3       1       1  $112,870
# 3     4     SicK    12       3       1       1  $112,650
# 4     5     cNed    12       4       2       1  $107,735

# %% [markdown]
# #Data Understanding

# %% [markdown]
# Dataset ini didapat di Kaggle - Valorant Esport

# %% [markdown]
# In [ ] :

# %%
df = pd.read_csv("/content/drive/MyDrive/Players.csv")

# %% [markdown]
# 1. **Cek Jumlah Baris Dan Kolom**

# %% [markdown]
# In[ ]:

# %%
print("Jumlah baris dan kolom:", df.shape)
# Out:
# Jumlah baris dan kolom: (500, 7)

# %% [markdown]
# Dataset ini memiliki 500 Baris dan 7 Kolom

# %% [markdown]
# **2. Cek Tipe Data Setiap Kolom**

# %% [markdown]
# In [ ] :

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Rank      500 non-null    int64
#  1   Player    500 non-null    object
#  2   Gold      500 non-null    int64
#  3   Silver    500 non-null    int64
#  4   Bronze    500 non-null    int64
#  5   S Tier    500 non-null    int64
#  6   Earnings  500 non-null    object
# dtypes: int64(5), object(2)
# memory usage: 27.5+ KB

# %% [markdown]
# **3. Tampilkan 5 data pertama dan terakhir untuk melihat isi datase (Jika baris banyak)**

# %%
df
# Out:
#      Rank      Player  Gold  Silver  Bronze  S Tier  Earnings
# 0       1       zombs    13       5       1       1  $113,550
# 1       2     ShahZaM    13       4       1       1  $113,450
# 2       3        dapr    14       3       1       1  $112,870
# 3       4        SicK    12       3       1       1  $112,650
# 4       5        cNed    12       4       2       1  $107,735
# ..    ...         ...   ...     ...     ...     ...       ...
# 495   496         Kim     3       4       1       0    $5,555
# 496   497        Less     3       1       1       0    $5,543
# 497   498  Senhoachic     7       2       5       0    $5,537
# 498   499       chase    19      10       2       0    $5,531
# 499   500     Harmful     6       4       2       0    $5,530
#
# [500 rows x 7 columns]

# %% [markdown]
# **4. Statistik Deskriptif**

# %%
df.describe()
# Out:
#              Rank        Gold      Silver      Bronze      S Tier
# count  500.000000  500.000000  500.000000  500.000000  500.000000
# mean   250.424000    6.912000    4.054000    1.666000    0.030000
# std    144.452002    4.755364    2.576113    1.461066    0.170758
# min      1.000000    0.000000    0.000000    0.000000    0.000000
# 25%    125.750000    3.000000    2.000000    1.000000    0.000000
# 50%    250.500000    6.000000    4.000000    1.000000    0.000000
# 75%    375.250000    9.000000    6.000000    2.000000    0.000000
# max    500.000000   26.000000   13.000000    8.000000    1.000000

# %% [markdown]
# #A. Pengecekan Terhadap Data

# %% [markdown]
# **1. Nilai yang hilang (Missing Values)**

# %%
import pandas as pd
df = pd.read_csv("/content/Players.csv")

# %% [markdown]
# in [ ] :

# %%
print((df.isna().sum() / len(df)) * 100)
# Out:
# Rank        0.0
# Player      0.0
# Gold        0.0
# Silver      0.0
# Bronze      0.0
# S Tier      0.0
# Earnings    0.0
# dtype: float64

# %% [markdown]
# **2. Duplicated Values**

# %% [markdown]
# in [ ]:

# %%
duplicate_rows = df[df.duplicated()]
print("Jumlah baris duplikat:", len(duplicate_rows))
# Out:
# Jumlah baris duplikat: 0

# %% [markdown]
# **3. Outliers**

# %% [markdown]
# IN [ ]:

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - (1.5 * iqr)
  upper_bound = q3 + (1.5 * iqr)
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df)) *100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

  results_df = pd.DataFrame(results)
  results_df.set_index('Kolom', inplace=True)
  results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

  display(results_df)
# Out:
# Kolom  Persentase Outliers
# Rank                   0.0
# Kolom  Persentase Outliers
# Rank                   0.0
# Gold                   2.2
# Kolom   Persentase Outliers
# Rank                    0.0
# Gold                    2.2
# Silver                  0.2
# Kolom   Persentase Outliers
# Rank                    0.0
# Gold                    2.2
# Silver                  0.2
# Bronze                 10.0
# Kolom   Persentase Outliers
# Rank                    0.0
# Gold                    2.2
# Silver                  0.2
# Bronze                 10.0
# S Tier                  3.0

# %%
df
# Out:
#      Rank      Player  Gold  Silver  Bronze  S Tier  Earnings
# 0       1       zombs    13       5       1       1  $113,550
# 1       2     ShahZaM    13       4       1       1  $113,450
# 2       3        dapr    14       3       1       1  $112,870
# 3       4        SicK    12       3       1       1  $112,650
# 4       5        cNed    12       4       2       1  $107,735
# ..    ...         ...   ...     ...     ...     ...       ...
# 495   496         Kim     3       4       1       0    $5,555
# 496   497        Less     3       1       1       0    $5,543
# 497   498  Senhoachic     7       2       5       0    $5,537
# 498   499       chase    19      10       2       0    $5,531
# 499   500     Harmful     6       4       2       0    $5,530
#
# [500 rows x 7 columns]

# %% [markdown]
# **4. Incosistent Value**
#
# Dari dataset yang diteliti, terlihat bahwasanya tidak ada nilai yang tidak konsisten

# %% [markdown]
# #Konstruksi Data (Construct Data) (Penambahan Kolom)
#
# **Menambahkan Kolom Total Medali**

# %%
df['Total Medali'] = df['Gold'] + df['Silver'] + df['Bronze']

# %%
print(df)
# Out:
#      Rank      Player  Gold  Silver  Bronze  S Tier  Earnings  Total Medali
# 0       1       zombs    13       5       1       1  $113,550            19
# 1       2     ShahZaM    13       4       1       1  $113,450            18
# 2       3        dapr    14       3       1       1  $112,870            18
# 3       4        SicK    12       3       1       1  $112,650            16
# 4       5        cNed    12       4       2       1  $107,735            18
# ..    ...         ...   ...     ...     ...     ...       ...           ...
# 495   496         Kim     3       4       1       0    $5,555             8
# 496   497        Less     3       1       1       0    $5,543             5
# 497   498  Senhoachic     7       2       5       0    $5,537            14
# 498   499       chase    19      10       2       0    $5,531            31
# 499   500     Harmful     6       4       2       0    $5,530            12
#
# [500 rows x 8 columns]

# %% [markdown]
# **Menambahkan Kolom Kategori Persentase Kemenangan**

# %%
total_pertandingan_mungkin = df['Total Medali'].max() * 3
df['Persentase Kemenangan'] = (df['Total Medali'] / total_pertandingan_mungkin) * 100

def kategori_persentase(persentase):
    if persentase >= 70:
        return 'Tinggi'
    elif persentase >= 40:
        return 'Sedang'
    else:
        return 'Rendah'

df['Kategori Persentase Kemenangan'] = df['Persentase Kemenangan'].apply(kategori_persentase)

df
# Out:
#      Rank      Player  Gold  Silver  Bronze  S Tier  Earnings  Total Medali  \
# 0       1       zombs    13       5       1       1  $113,550            19
# 1       2     ShahZaM    13       4       1       1  $113,450            18
# 2       3        dapr    14       3       1       1  $112,870            18
# 3       4        SicK    12       3       1       1  $112,650            16
# 4       5        cNed    12       4       2       1  $107,735            18
# ..    ...         ...   ...     ...     ...     ...       ...           ...
# 495   496         Kim     3       4       1       0    $5,555             8
# 496   497        Less     3       1       1       0    $5,543             5
# 497   498  Senhoachic     7       2       5       0    $5,537            14
# 498   499       chase    19      10       2       0    $5,531            31
# 499   500     Harmful     6       4       2       0    $5,530            12
#
# ...

# %% [markdown]
# #REDUKSI DATA (Data Reduction)

# %% [markdown]
# Tujuan dari Data Reduction ini agar membuat dataset menjadi lebih ringkas dan Mengurangi ukuran file dan fokus pada informasi utama

# %%
columns_to_drop = ['Total Medali', 'Persentase Kemenangan']
df_cleaned = df.drop(columns=columns_to_drop, errors='ignore')

# %%
df
# Out:
#      Rank      Player  Gold  Silver  Bronze  S Tier  Earnings
# 0       1       zombs    13       5       1       1  $113,550
# 1       2     ShahZaM    13       4       1       1  $113,450
# 2       3        dapr    14       3       1       1  $112,870
# 3       4        SicK    12       3       1       1  $112,650
# 4       5        cNed    12       4       2       1  $107,735
# ..    ...         ...   ...     ...     ...     ...       ...
# 495   496         Kim     3       4       1       0    $5,555
# 496   497        Less     3       1       1       0    $5,543
# 497   498  Senhoachic     7       2       5       0    $5,537
# 498   499       chase    19      10       2       0    $5,531
# 499   500     Harmful     6       4       2       0    $5,530
#
# [500 rows x 7 columns]
